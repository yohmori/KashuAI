# %%
# ffmpeg for preprocessing
# forrier transformation

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import ffmpeg

# %%
audio = './data/sakura_wav.wav'

# %%
y, sr = librosa.load(audio)

# %%
y
# Out:
# array([-5.3726822e-02, -9.6176177e-02, -6.2486175e-02, ...,
#        -5.9096175e-05, -6.5184271e-05,  0.0000000e+00], dtype=float32)

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveshow(y, sr=sr)
plt.title('Waveform')
plt.show()

# %%
freqs, times, mags = librosa.reassigned_spectrogram(y=y, sr=sr, n_fft=64)
mags_db = librosa.amplitude_to_db(mags, ref=np.max)

# %%
fig, ax = plt.subplots(nrows=2, sharex=True, sharey=True)
img = librosa.display.specshow(mags_db, x_axis="s", y_axis="linear", sr=sr,
                         hop_length=64//4, ax=ax[0])
ax[0].set(title="Spectrogram", xlabel=None)
ax[0].label_outer()
ax[1].scatter(times, freqs, c=mags_db, cmap="magma", alpha=0.1, s=5)
ax[1].set_title("Reassigned spectrogram")
fig.colorbar(img, ax=ax, format="%+2.f dB")
